# %%
pip install twint
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nest-asyncio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import twint
import nest_asyncio
nest_asyncio.apply()

# %%
c=twint.Config()

# %%
c.Username = "elonmusk"
c.Search = "Tesla"
c.Store_csv=True

c.Output="none"
a=twint.run.Search(c)
# Out:
# CRITICAL:root:twint.get:User:'NoneType' object is not subscriptable
# 1269111460493357057 2020-06-06 09:08:45 India Standard Time <elonmusk> Order a Tesla online in 2 mins at  http://Tesla.com
# 1269110658844393477 2020-06-06 09:05:34 India Standard Time <elonmusk> Tesla Model Y review by Dan Neil  https://www.wsj.com/articles/is-teslas-model-y-crossover-the-worlds-best-car-11591365620 …
# 1266436499341545472 2020-05-29 23:59:25 India Standard Time <elonmusk> Worth noting that, as of Jan 1, Tesla buyers no longer received any federal tax credit. Model 3 led despite this disadvantage.
# 1262526115266035715 2020-05-19 05:00:57 India Standard Time <elonmusk> Tesla Full Self-Driving option cost rises by ~$1000 worldwide on July 1st. Order a Tesla online in less than 2 minutes at  https://www.tesla.com/
# ...

# %%
# !twint -s Tesla -o Tesla.csv --csv
